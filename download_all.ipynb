# %%
import os
import zipfile
import requests
from datetime import datetime
import re
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %%
BASE_URL = "https://downloads.climatetrace.org/v5.1.0/sector_packages"

SECTORS = [
    "manufacturing",
    "mineral_extraction",
    "power",
]

EMISSION_TYPES = {
    "co2e_100yr": "co2e_100yr",
    "co2e_20yr": "co2e_20yr",
    "co2": "co2",
    "ch4": "ch4",
    "n2o": "n2o",
    "pm2.5": "pm2_5",
    "vocs": "vocs",
    "co": "co",
    "nh3": "nh3",
    "nox": "nox",
    "so2": "so2",
    "bc": "bc",
    "oc": "oc",
}

DOWNLOAD_DIR = "downloads"
EXTRACT_DIR = "extracted"

os.makedirs(DOWNLOAD_DIR, exist_ok=True)
os.makedirs(EXTRACT_DIR, exist_ok=True)

def log(message):
    ts = datetime.utcnow().isoformat(timespec="seconds")
    print(f"[{ts}] {message}")

def download_zip(url, zip_path):
    r = requests.get(url, stream=True, timeout=60)
    if r.status_code == 200:
        with open(zip_path, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)
        return "downloaded"
    elif r.status_code == 404:
        return "missing"
    else:
        return f"http_{r.status_code}"

def extract_zip(zip_path, extract_to):
    os.makedirs(extract_to, exist_ok=True)
    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(extract_to)

for sector in SECTORS:
    for emission_name, emission_slug in EMISSION_TYPES.items():

        url = f"{BASE_URL}/{emission_slug}/{sector}.zip"
        zip_filename = f"{sector}__{emission_name}.zip"
        zip_path = os.path.join(DOWNLOAD_DIR, zip_filename)
        extract_path = os.path.join(EXTRACT_DIR, sector, emission_name)

        try:
            status = download_zip(url, zip_path)

            if status == "downloaded":
                extract_zip(zip_path, extract_path)
                log(f"OK     | {sector:<18} | {emission_name:<10} | extracted → {extract_path}")
            elif status == "missing":
                log(f"MISSING| {sector:<18} | {emission_name:<10} | not available")
            else:
                log(f"ERROR  | {sector:<18} | {emission_name:<10} | {status}")

        except Exception as e:
            log(f"EXCEPT | {sector:<18} | {emission_name:<10} | {e}")
# Out:
# /var/folders/7b/k9t7lbq9461cdn3czk_fmvxm0000gn/T/ipykernel_88571/2518179863.py:37: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   ts = datetime.utcnow().isoformat(timespec="seconds")
# [2025-12-15T04:52:13] OK     | manufacturing      | co2e_100yr | extracted → extracted/manufacturing/co2e_100yr
# [2025-12-15T04:52:15] OK     | manufacturing      | co2e_20yr  | extracted → extracted/manufacturing/co2e_20yr
# [2025-12-15T04:52:20] OK     | manufacturing      | co2        | extracted → extracted/manufacturing/co2
# [2025-12-15T04:52:23] OK     | manufacturing      | ch4        | extracted → extracted/manufacturing/ch4
# [2025-12-15T04:52:28] OK     | manufacturing      | n2o        | extracted → extracted/manufacturing/n2o
# [2025-12-15T04:52:34] OK     | manufacturing      | pm2.5      | extracted → extracted/manufacturing/pm2.5
# [2025-12-15T04:52:34] OK     | manufacturing      | vocs       | extracted → extracted/manufacturing/vocs
# [2025-12-15T04:52:39] OK     | manufacturing      | co         | extracted → extracted/manufacturing/co
# [2025-12-15T04:52:44] OK     | manufacturing      | nh3        | extracted → extracted/manufacturing/nh3
# [2025-12-15T04:52:48] OK     | manufacturing      | nox        | extracted → extracted/manufacturing/nox
# [2025-12-15T04:52:54] OK     | manufacturing      | so2        | extracted → extracted/manufacturing/so2
# [2025-12-15T04:53:00] OK     | manufacturing      | bc         | extracted → extracted/manufacturing/bc
# [2025-12-15T04:53:05] OK     | manufacturing      | oc         | extracted → extracted/manufacturing/oc
# [2025-12-15T04:53:06] OK     | mineral_extraction | co2e_100yr | extracted → extracted/mineral_extraction/co2e_100yr
# [2025-12-15T04:53:07] OK     | mineral_extraction | co2e_20yr  | extracted → extracted/mineral_extraction/co2e_20yr
# [2025-12-15T04:53:07] OK     | mineral_extraction | co2        | extracted → extracted/mineral_extraction/co2
# [2025-12-15T04:53:08] OK     | mineral_extraction | ch4        | extracted → extracted/mineral_extraction/ch4
# [2025-12-15T04:53:09] OK     | mineral_extraction | n2o        | extracted → extracted/mineral_extraction/n2o
# [2025-12-15T04:53:11] OK     | mineral_extraction | pm2.5      | extracted → extracted/mineral_extraction/pm2.5
# [2025-12-15T04:53:12] OK     | mineral_extraction | vocs       | extracted → extracted/mineral_extraction/vocs
# [2025-12-15T04:53:13] OK     | mineral_extraction | co         | extracted → extracted/mineral_extraction/co
# [2025-12-15T04:53:13] OK     | mineral_extraction | nh3        | extracted → extracted/mineral_extraction/nh3
# [2025-12-15T04:53:14] OK     | mineral_extraction | nox        | extracted → extracted/mineral_extraction/nox
# [2025-12-15T04:53:15] OK     | mineral_extraction | so2        | extracted → extracted/mineral_extraction/so2
# [2025-12-15T04:53:15] OK     | mineral_extraction | bc         | extracted → extracted/mineral_extraction/bc
# [2025-12-15T04:53:16] OK     | mineral_extraction | oc         | extracted → extracted/mineral_extraction/oc
# [2025-12-15T04:53:18] OK     | power              | co2e_100yr | extracted → extracted/power/co2e_100yr
# [2025-12-15T04:53:20] OK     | power              | co2e_20yr  | extracted → extracted/power/co2e_20yr
# [2025-12-15T04:53:22] OK     | power              | co2        | extracted → extracted/power/co2
# [2025-12-15T04:53:24] OK     | power              | ch4        | extracted → extracted/power/ch4
# [2025-12-15T04:53:25] OK     | power              | n2o        | extracted → extracted/power/n2o
# [2025-12-15T04:53:26] OK     | power              | pm2.5      | extracted → extracted/power/pm2.5
# [2025-12-15T04:53:26] OK     | power              | vocs       | extracted → extracted/power/vocs
# [2025-12-15T04:53:28] OK     | power              | co         | extracted → extracted/power/co
# [2025-12-15T04:53:30] OK     | power              | nh3        | extracted → extracted/power/nh3
# [2025-12-15T04:53:31] OK     | power              | nox        | extracted → extracted/power/nox
# [2025-12-15T04:53:34] OK     | power              | so2        | extracted → extracted/power/so2
# [2025-12-15T04:53:36] OK     | power              | bc         | extracted → extracted/power/bc
# [2025-12-15T04:53:38] OK     | power              | oc         | extracted → extracted/power/oc

# %%
import os
import sys

def print_tree(root_path, prefix=""):
    try:
        items = sorted(os.listdir(root_path))
    except PermissionError:
        print(prefix + "└── [Permission Denied]")
        return

    for index, item in enumerate(items):
        path = os.path.join(root_path, item)
        is_last = index == len(items) - 1

        connector = "└── " if is_last else "├── "
        print(prefix + connector + item)

        if os.path.isdir(path):
            extension = "    " if is_last else "│   "
            print_tree(path, prefix + extension)

print_tree('/Users/annayuen/Desktop/ERG/Master Thesis/industrial_decarb/climate_trace_data/extracted/manufacturing')
# Out:
# ├── .DS_Store
# ├── bc
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       └── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ├── ch4
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_country_emissions_v5_1_0.csv
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_country_emissions_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_country_emissions_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_country_emissions_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_country_emissions_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_country_emissions_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_country_emissions_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_country_emissions_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_country_emissions_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_country_emissions_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_country_emissions_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_country_emissions_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_country_emissions_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# │       └── wood-and-wood-products_country_emissions_v5_1_0.csv
# ├── co
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       └── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ├── co2
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_country_emissions_v5_1_0.csv
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_country_emissions_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_country_emissions_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_country_emissions_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_country_emissions_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_country_emissions_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_country_emissions_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_country_emissions_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_country_emissions_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_country_emissions_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_country_emissions_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_country_emissions_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_country_emissions_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# │       └── wood-and-wood-products_country_emissions_v5_1_0.csv
# ├── co2e_100yr
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_country_emissions_v5_1_0.csv
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_country_emissions_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_country_emissions_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_country_emissions_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_country_emissions_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_country_emissions_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_country_emissions_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_country_emissions_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_country_emissions_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_country_emissions_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_country_emissions_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_country_emissions_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_country_emissions_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# │       └── wood-and-wood-products_country_emissions_v5_1_0.csv
# ├── co2e_20yr
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_country_emissions_v5_1_0.csv
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_country_emissions_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_country_emissions_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_country_emissions_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_country_emissions_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_country_emissions_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_country_emissions_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_country_emissions_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_country_emissions_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_country_emissions_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_country_emissions_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_country_emissions_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_country_emissions_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# │       └── wood-and-wood-products_country_emissions_v5_1_0.csv
# ├── n2o
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_country_emissions_v5_1_0.csv
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_country_emissions_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_country_emissions_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_country_emissions_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_country_emissions_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_country_emissions_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_country_emissions_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_country_emissions_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_country_emissions_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_country_emissions_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_country_emissions_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_country_emissions_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_country_emissions_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# │       └── wood-and-wood-products_country_emissions_v5_1_0.csv
# ├── nh3
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       └── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ├── nox
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       └── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ├── oc
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       └── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ├── pm2.5
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       └── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ├── so2
# │   ├── .DS_Store
# │   ├── ABOUT_THE_DATA
# │   │   ├── about_the_data_v5_1_0.pdf
# │   │   └── detailed_data_schema_v5_1_0.csv
# │   └── DATA
# │       ├── aluminum_emissions_sources_confidence_v5_1_0.csv
# │       ├── aluminum_emissions_sources_ownership_v5_1_0.csv
# │       ├── aluminum_emissions_sources_v5_1_0.csv
# │       ├── cement_emissions_sources_confidence_v5_1_0.csv
# │       ├── cement_emissions_sources_ownership_v5_1_0.csv
# │       ├── cement_emissions_sources_v5_1_0.csv
# │       ├── chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── chemicals_emissions_sources_ownership_v5_1_0.csv
# │       ├── chemicals_emissions_sources_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv
# │       ├── food-beverage-tobacco_emissions_sources_v5_1_0.csv
# │       ├── glass_emissions_sources_confidence_v5_1_0.csv
# │       ├── glass_emissions_sources_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_confidence_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
# │       ├── iron-and-steel_emissions_sources_v5_1_0.csv
# │       ├── lime_emissions_sources_confidence_v5_1_0.csv
# │       ├── lime_emissions_sources_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-chemicals_emissions_sources_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-manufacturing_emissions_sources_v5_1_0.csv
# │       ├── other-metals_emissions_sources_confidence_v5_1_0.csv
# │       ├── other-metals_emissions_sources_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
# │       ├── petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_confidence_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv
# │       ├── pulp-and-paper_emissions_sources_v5_1_0.csv
# │       ├── textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv
# │       └── textiles-leather-apparel_emissions_sources_v5_1_0.csv
# └── vocs
#     ├── .DS_Store
#     ├── ABOUT_THE_DATA
#     │   ├── about_the_data_v5_1_0.pdf
#     │   └── detailed_data_schema_v5_1_0.csv
#     └── DATA
#         ├── aluminum_emissions_sources_ownership_v5_1_0.csv
#         ├── cement_emissions_sources_ownership_v5_1_0.csv
#         ├── chemicals_emissions_sources_ownership_v5_1_0.csv
#         ├── iron-and-steel_emissions_sources_ownership_v5_1_0.csv
#         ├── petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv
#         └── pulp-and-paper_emissions_sources_ownership_v5_1_0.csv

# %%
FILE_RE = re.compile(r"(.+)_emissions_v5_1_0\.csv$")

def normalize_columns(df):
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
        .str.replace(r"[^\w_]", "", regex=True)
    )
    return df

def process_csv(path, sector, subsector, emission_type, version):
    df = pd.read_csv(path, low_memory=False)

    df = normalize_columns(df)

    # Add explicit metadata columns
    df["sector"] = sector
    df["subsector"] = subsector
    df["emission_type"] = emission_type
    df["source_version"] = version

    return df

def write_parquet(df, sector, subsector, emission_type, out_base):
    out_dir = os.path.join(
        out_base,
        f"sector={sector}",
        f"emission={emission_type}",
        f"subsector={subsector}"
    )
    os.makedirs(out_dir, exist_ok=True)

    table = pa.Table.from_pandas(df, preserve_index=False)

    pq.write_table(
        table,
        os.path.join(out_dir, "part-000.parquet"),
        compression="zstd",
        use_dictionary=True
    )

    print(f"✔ {subsector}: {len(df):,} rows, {df.shape[1]} columns")

# for file in sorted(os.listdir(RAW_BASE)):
#     match = FILE_RE.match(file)
#     if not match:
#         print(f"{file} not matched.")
#         continue

#     subsector = match.group(1)
#     csv_path = os.path.join(RAW_BASE, file)

#     print(f"Processing {file}")
#     df = process_csv(csv_path, subsector)
#     write_parquet(df, subsector)
# Out:
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns

# %%
for sector in SECTORS:
    for emission_type in EMISSION_TYPES.keys():
        print(f"{sector} - {emission_type}")
        RAW_BASE = f"extracted/{sector}/{emission_type}/DATA"
        OUT_BASE = "parquet/emissions"

        SECTOR = f"{sector}"
        EMISSION_TYPE = emission_type
        VERSION = "v5.1.0"

        for file in sorted(os.listdir(RAW_BASE)):
            match = FILE_RE.match(file)
            if not match:
                print(f"{file} not matched.")
                continue

            subsector = match.group(1)
            csv_path = os.path.join(RAW_BASE, file)

            print(f"Processing {file}")
            df = process_csv(csv_path, subsector)
            write_parquet(df, subsector)
# Out:
# manufacturing - co2e_100yr
# aluminum_country_emissions_v5_1_0.csv not matched.
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_country_emissions_v5_1_0.csv not matched.
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_country_emissions_v5_1_0.csv not matched.
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_country_emissions_v5_1_0.csv not matched.
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_country_emissions_v5_1_0.csv not matched.
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_country_emissions_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_country_emissions_v5_1_0.csv not matched.
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_country_emissions_v5_1_0.csv not matched.
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_country_emissions_v5_1_0.csv not matched.
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_country_emissions_v5_1_0.csv not matched.
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_country_emissions_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_country_emissions_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_country_emissions_v5_1_0.csv not matched.
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# wood-and-wood-products_country_emissions_v5_1_0.csv not matched.
# manufacturing - co2e_20yr
# aluminum_country_emissions_v5_1_0.csv not matched.
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_country_emissions_v5_1_0.csv not matched.
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_country_emissions_v5_1_0.csv not matched.
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_country_emissions_v5_1_0.csv not matched.
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_country_emissions_v5_1_0.csv not matched.
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_country_emissions_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_country_emissions_v5_1_0.csv not matched.
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_country_emissions_v5_1_0.csv not matched.
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_country_emissions_v5_1_0.csv not matched.
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_country_emissions_v5_1_0.csv not matched.
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_country_emissions_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_country_emissions_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_country_emissions_v5_1_0.csv not matched.
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# wood-and-wood-products_country_emissions_v5_1_0.csv not matched.
# manufacturing - co2
# aluminum_country_emissions_v5_1_0.csv not matched.
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_country_emissions_v5_1_0.csv not matched.
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_country_emissions_v5_1_0.csv not matched.
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_country_emissions_v5_1_0.csv not matched.
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_country_emissions_v5_1_0.csv not matched.
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_country_emissions_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_country_emissions_v5_1_0.csv not matched.
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_country_emissions_v5_1_0.csv not matched.
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_country_emissions_v5_1_0.csv not matched.
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_country_emissions_v5_1_0.csv not matched.
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_country_emissions_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_country_emissions_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_country_emissions_v5_1_0.csv not matched.
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# wood-and-wood-products_country_emissions_v5_1_0.csv not matched.
# manufacturing - ch4
# aluminum_country_emissions_v5_1_0.csv not matched.
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_country_emissions_v5_1_0.csv not matched.
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_country_emissions_v5_1_0.csv not matched.
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_country_emissions_v5_1_0.csv not matched.
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_country_emissions_v5_1_0.csv not matched.
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_country_emissions_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_country_emissions_v5_1_0.csv not matched.
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_country_emissions_v5_1_0.csv not matched.
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_country_emissions_v5_1_0.csv not matched.
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_country_emissions_v5_1_0.csv not matched.
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_country_emissions_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_country_emissions_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_country_emissions_v5_1_0.csv not matched.
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# wood-and-wood-products_country_emissions_v5_1_0.csv not matched.
# manufacturing - n2o
# aluminum_country_emissions_v5_1_0.csv not matched.
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_country_emissions_v5_1_0.csv not matched.
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_country_emissions_v5_1_0.csv not matched.
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_country_emissions_v5_1_0.csv not matched.
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_country_emissions_v5_1_0.csv not matched.
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_country_emissions_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_country_emissions_v5_1_0.csv not matched.
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_country_emissions_v5_1_0.csv not matched.
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_country_emissions_v5_1_0.csv not matched.
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_country_emissions_v5_1_0.csv not matched.
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_country_emissions_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_country_emissions_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_country_emissions_v5_1_0.csv not matched.
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# wood-and-wood-products_country_emissions_v5_1_0.csv not matched.
# manufacturing - pm2.5
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# manufacturing - vocs
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# manufacturing - co
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# manufacturing - nh3
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# manufacturing - nox
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# manufacturing - so2
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# manufacturing - bc
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# manufacturing - oc
# aluminum_emissions_sources_confidence_v5_1_0.csv not matched.
# aluminum_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing aluminum_emissions_sources_v5_1_0.csv
# ✔ aluminum: 17,727 rows, 49 columns
# cement_emissions_sources_confidence_v5_1_0.csv not matched.
# cement_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing cement_emissions_sources_v5_1_0.csv
# ✔ cement: 123,120 rows, 49 columns
# chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# chemicals_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing chemicals_emissions_sources_v5_1_0.csv
# ✔ chemicals: 24,795 rows, 49 columns
# food-beverage-tobacco_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing food-beverage-tobacco_emissions_sources_v5_1_0.csv
# ✔ food-beverage-tobacco: 857,679 rows, 49 columns
# glass_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing glass_emissions_sources_v5_1_0.csv
# ✔ glass: 27,474 rows, 49 columns
# iron-and-steel_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-and-steel_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-and-steel_emissions_sources_v5_1_0.csv
# ✔ iron-and-steel: 54,435 rows, 49 columns
# lime_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing lime_emissions_sources_v5_1_0.csv
# ✔ lime: 93,252 rows, 49 columns
# other-chemicals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-chemicals_emissions_sources_v5_1_0.csv
# ✔ other-chemicals: 25,023 rows, 49 columns
# other-manufacturing_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-manufacturing_emissions_sources_v5_1_0.csv
# ✔ other-manufacturing: 22,686 rows, 49 columns
# other-metals_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing other-metals_emissions_sources_v5_1_0.csv
# ✔ other-metals: 23,826 rows, 49 columns
# petrochemical-steam-cracking_emissions_sources_confidence_v5_1_0.csv not matched.
# petrochemical-steam-cracking_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing petrochemical-steam-cracking_emissions_sources_v5_1_0.csv
# ✔ petrochemical-steam-cracking: 13,566 rows, 49 columns
# pulp-and-paper_emissions_sources_confidence_v5_1_0.csv not matched.
# pulp-and-paper_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing pulp-and-paper_emissions_sources_v5_1_0.csv
# ✔ pulp-and-paper: 20,007 rows, 49 columns
# textiles-leather-apparel_emissions_sources_confidence_v5_1_0.csv not matched.
# Processing textiles-leather-apparel_emissions_sources_v5_1_0.csv
# ✔ textiles-leather-apparel: 611,952 rows, 49 columns
# mineral_extraction - co2e_100yr
# bauxite-mining_country_emissions_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_country_emissions_v5_1_0.csv not matched.
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,098 rows, 49 columns
# iron-mining_country_emissions_v5_1_0.csv not matched.
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# other-mining-quarrying_country_emissions_v5_1_0.csv not matched.
# rock-quarrying_country_emissions_v5_1_0.csv not matched.
# sand-quarrying_country_emissions_v5_1_0.csv not matched.
# mineral_extraction - co2e_20yr
# bauxite-mining_country_emissions_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_country_emissions_v5_1_0.csv not matched.
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,098 rows, 49 columns
# iron-mining_country_emissions_v5_1_0.csv not matched.
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# other-mining-quarrying_country_emissions_v5_1_0.csv not matched.
# rock-quarrying_country_emissions_v5_1_0.csv not matched.
# sand-quarrying_country_emissions_v5_1_0.csv not matched.
# mineral_extraction - co2
# bauxite-mining_country_emissions_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_country_emissions_v5_1_0.csv not matched.
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,098 rows, 49 columns
# iron-mining_country_emissions_v5_1_0.csv not matched.
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# other-mining-quarrying_country_emissions_v5_1_0.csv not matched.
# rock-quarrying_country_emissions_v5_1_0.csv not matched.
# sand-quarrying_country_emissions_v5_1_0.csv not matched.
# mineral_extraction - ch4
# bauxite-mining_country_emissions_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_country_emissions_v5_1_0.csv not matched.
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,098 rows, 49 columns
# iron-mining_country_emissions_v5_1_0.csv not matched.
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# other-mining-quarrying_country_emissions_v5_1_0.csv not matched.
# rock-quarrying_country_emissions_v5_1_0.csv not matched.
# sand-quarrying_country_emissions_v5_1_0.csv not matched.
# mineral_extraction - n2o
# bauxite-mining_country_emissions_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_country_emissions_v5_1_0.csv not matched.
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,098 rows, 49 columns
# iron-mining_country_emissions_v5_1_0.csv not matched.
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# other-mining-quarrying_country_emissions_v5_1_0.csv not matched.
# rock-quarrying_country_emissions_v5_1_0.csv not matched.
# sand-quarrying_country_emissions_v5_1_0.csv not matched.
# mineral_extraction - pm2.5
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,041 rows, 49 columns
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# mineral_extraction - vocs
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# mineral_extraction - co
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,041 rows, 49 columns
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# mineral_extraction - nh3
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,041 rows, 49 columns
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# mineral_extraction - nox
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,041 rows, 49 columns
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# mineral_extraction - so2
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,041 rows, 49 columns
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# mineral_extraction - bc
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,041 rows, 49 columns
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# mineral_extraction - oc
# bauxite-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# bauxite-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing bauxite-mining_emissions_sources_v5_1_0.csv
# ✔ bauxite-mining: 15,618 rows, 49 columns
# copper-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# copper-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing copper-mining_emissions_sources_v5_1_0.csv
# ✔ copper-mining: 52,041 rows, 49 columns
# iron-mining_emissions_sources_confidence_v5_1_0.csv not matched.
# iron-mining_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing iron-mining_emissions_sources_v5_1_0.csv
# ✔ iron-mining: 42,978 rows, 49 columns
# power - co2e_100yr
# electricity-generation_country_emissions_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,474 rows, 49 columns
# heat-plants_country_emissions_v5_1_0.csv not matched.
# other-energy-use_country_emissions_v5_1_0.csv not matched.
# power - co2e_20yr
# electricity-generation_country_emissions_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,474 rows, 49 columns
# heat-plants_country_emissions_v5_1_0.csv not matched.
# other-energy-use_country_emissions_v5_1_0.csv not matched.
# power - co2
# electricity-generation_country_emissions_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,474 rows, 49 columns
# heat-plants_country_emissions_v5_1_0.csv not matched.
# other-energy-use_country_emissions_v5_1_0.csv not matched.
# power - ch4
# electricity-generation_country_emissions_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,474 rows, 49 columns
# heat-plants_country_emissions_v5_1_0.csv not matched.
# other-energy-use_country_emissions_v5_1_0.csv not matched.
# power - n2o
# electricity-generation_country_emissions_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,474 rows, 49 columns
# heat-plants_country_emissions_v5_1_0.csv not matched.
# other-energy-use_country_emissions_v5_1_0.csv not matched.
# power - pm2.5
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 530,992 rows, 49 columns
# power - vocs
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# power - co
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,360 rows, 49 columns
# power - nh3
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,360 rows, 49 columns
# power - nox
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 530,992 rows, 49 columns
# power - so2
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 530,992 rows, 49 columns
# power - bc
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,360 rows, 49 columns
# power - oc
# electricity-generation_emissions_sources_confidence_v5_1_0.csv not matched.
# electricity-generation_emissions_sources_ownership_v5_1_0.csv not matched.
# Processing electricity-generation_emissions_sources_v5_1_0.csv
# ✔ electricity-generation: 540,360 rows, 49 columns

# %%
# example query of the parquet files. 
import duckdb
import os

# Path to your local Parquet data
PARQUET_BASE = "parquet/emissions"

# Output master file
MASTER_PARQUET = "facility_master.parquet"

# Initialize DuckDB in-memory connection
con = duckdb.connect()

# Step 1: Find all Parquet files recursively
parquet_files = []
for root, dirs, files in os.walk(PARQUET_BASE):
    for file in files:
        if file.endswith(".parquet"):
            parquet_files.append(os.path.join(root, file))

print(f"Found {len(parquet_files)} Parquet files.")

# Step 2: Build SQL UNION query over all files
# This keeps all columns, adds partition metadata if missing
queries = []
for f in parquet_files:
    # Extract sector and emission_type from folder structure
    parts = f.split(os.sep)
    # Adjust based on your folder layout
    try:
        sector = [p for p in parts if p.startswith("sector=")][0].split("=")[1]
        emission_type = [p for p in parts if p.startswith("emission=")][0].split("=")[1]
    except IndexError:
        sector = None
        emission_type = None

    q = f"""
    SELECT *, '{sector}' AS sector, '{emission_type}' AS emission_type
    FROM '{f}'
    """
    queries.append(q)

full_query = " UNION ALL ".join(queries)

# Step 3: Aggregate if needed (optional: here we just combine all rows)
print("Combining all files into master Parquet...")
con.execute(f"""
CREATE TABLE facility_master AS
{full_query}
""")

# Step 4: Export to Parquet
print(f"Writing master Parquet to {MASTER_PARQUET} ...")
con.execute(f"COPY facility_master TO '{MASTER_PARQUET}' (FORMAT PARQUET);")

print("Done! Master Parquet ready for local analysis or S3 upload.")
# Out:
# Found 204 Parquet files.
# Combining all files into master Parquet...
# Writing master Parquet to facility_master.parquet ...
# Done! Master Parquet ready for local analysis or S3 upload.

# %%
res = con.execute("""
SELECT *
FROM facility_master
""").df()
res.head()

# %%
res.source_name.unique()
# Out:
# array(['BALASHI', 'TAKAKHIL'], dtype=object)
